# %% [markdown]
# # Probability

# %% [markdown]
# ## Definition:

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Experiment/Trial, Event and Sample Space:

# %% [markdown]
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Mutually Exclusive Events, Independent Events and Complementary Events:

# %% [markdown]
# ![Capture7.PNG](attachment:Capture7.PNG)

# %% [markdown]
# ![Capture4.PNG](attachment:Capture4.PNG)

# %% [markdown]
# ![Capture5.PNG](attachment:Capture5.PNG)

# %% [markdown]
# ![Capture6.PNG](attachment:Capture6.PNG)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Rule of Multiplication:

# %% [markdown]
# ![Capture8.PNG](attachment:Capture8.PNG)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Rule of Addition:

# %% [markdown]
# ![Capture9.PNG](attachment:Capture9.PNG)
